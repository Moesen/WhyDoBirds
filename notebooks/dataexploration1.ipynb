# %%
import pandas as pd
import numpy as np
from pathlib import Path
import src
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv(src.data_processed_path() / "1000/LBBG_ZEEBRUGGE.txt", sep="\t")
df.shape
# Out:
# (100000, 257)

# %%
cols = [
 'decimalLatitude',
 'decimalLongitude',
]
df[cols].isna().sum()
# Out:
# decimalLatitude     0
# decimalLongitude    0
# dtype: int64

# %%
arr = df[cols].to_numpy()
plt.scatter(*arr.T)
plt.show()

# %%
fig = px.scatter_geo(df, lat=cols[0], lon=cols[1])
fig.show()
